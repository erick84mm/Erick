# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv('dataset2.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
data_no_out = dataset.drop([4,6])
X_no_out = data_no_out.iloc[:, :-1].values
y_no_out = data_no_out.iloc[:, -1].values
X = X_no_out
y = y_no_out

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %%
#plt.scatter(X, y, color = "red")
plt.plot(X_train, regressor.predict(X_train), color = "blue")
plt.title("Input vs Target (full plot)")
plt.xlabel("Input")
plt.ylabel("Target")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-2d1c53afb596> in <module>()
# ----> 1 Q1 = np.quantile(X, 0.25)
#       2 Q3 = np.quantile(X,0.75)
#
# AttributeError: module 'numpy' has no attribute 'quantile'
