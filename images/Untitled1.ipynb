# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import GaussianNB
from matplotlib.colors import ListedColormap
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
dataset = pd.read_csv('dataset2.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
dataset
# Out:
#               f1           f2           f3           f4          f5  target
# 0    -272.454777   468.613536  -842.286623   572.695784 -687.899895       0
# 1    -308.353837   700.943567    92.784465   -80.491097 -688.127360       0
# 2    -274.644338  1181.384499  1743.731899   353.031873 -687.953315       0
# 3    -270.346258   620.286159   937.707794   312.270129 -688.011625       0
# 4    -289.421521   825.666823   197.163482   195.133563 -687.980375       0
# 5    -236.245409   308.881490  1009.984016  1294.700311 -687.870870       0
# 6    -242.679401  1314.421319   -40.554788  -428.055576 -687.903184       0
# 7    -271.202035   270.681498    23.692251  -249.230720 -687.952375       0
# 8    -228.979864  1317.225663   911.154049   495.527427 -687.978660       0
# 9    -274.418293   195.050943  1013.811372   127.115999 -687.994298       0
# 10   -206.456881   480.732629   881.385593   314.453345 -688.042579       0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
## Feature Scaling is needed in Logistic Regression
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
## Classifier 
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
## K neighers neighbors
classifier = KNeighborsClassifier()
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
##SVC
classifier = SVC(kernel = "rbf")
classifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
##Bayes
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None)

# %%
## Predictions
y_pred = classifier.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[568,   0],
#        [ 32,   0]])

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=1)
X_pca_train = pca.fit_transform(X_train)

# %%
y_pred = classifier.predict(X)
#plt.scatter(pca.fit_transform(X)[:,0], pca.fit_transform(X)[:,1])
#plt.scatter(pca.fit_transform(X)[:,0], y_pred)

pos = dataset.where()
## positives
plt.scatter(pca.fit_transform(X), y, color="yellow")

##negatives
plt.show()

# %%
from sklearn import linear_model

pca = PCA(n_components=2)
X_pca_train = pca.fit_transform(X_train)

clf = linear_model.SGDClassifier(max_iter=1000, tol=1e-3)
clf.fit(X_train, y_train)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=1000, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=None,
#        shuffle=True, tol=0.001, verbose=0, warm_start=False)

# %%
y_pred = clf.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[567,   1],
#        [ 32,   0]])

# %%
pos = dataset.loc[dataset['target'] == 1]
neg = dataset.loc[dataset['target'] == 0]

pca = PCA(n_components=2)

X_pca_train = pca.fit_transform(X_train)

clf = linear_model.SGDClassifier(max_iter=1000, tol=1e-3)
clf.fit(X_train, y_train)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=1000, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=None,
#        shuffle=True, tol=0.001, verbose=0, warm_start=False)

# %%
plt.scatter(pca.fit_transform(pos)[:,0], pca.fit_transform(pos)[:,1], color="yellow")
plt.scatter(pca.fit_transform(neg)[:,0], pca.fit_transform(neg)[:,1], y, color="blue")

##negatives
plt.show()
